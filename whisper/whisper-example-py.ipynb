# %% [markdown]
# # Speech Transcription on IPUs using Whisper - Inference
#
# This notebook demonstrates speech transcription on the IPU using the [Whisper implementation in the Hugging Face Transformers library](https://huggingface.co/spaces/openai/whisper) alongside [Optimum Graphcore](https://github.com/huggingface/optimum-graphcore).
#
# Whisper is a versatile speech recognition model that can transcribe speech as well as perform multi-lingual translation and recognition tasks.
# It was trained on diverse datasets to give human-level speech recognition performance without the need for fine tuning.
#
# Optimum Graphcore is the interface between the Hugging Face Transformers library and [Graphcore IPUs](https://www.graphcore.ai/products/ipu).
# It provides a set of tools enabling model parallelization and loading on IPUs, training and fine-tuning on all the tasks already supported by Transformers while being compatible with the Hugging Face Hub and every model available on it out of the box.
#
# > **Hardware requirements:** The Whisper models `whisper-tiny`, `whisper-base` and `whisper-small` can run two replicas on the smallest IPU-POD4 machine. The most capable model, `whisper-large`, will need to use either an IPU-POD16 or a Bow Pod16 machine. Please contact Graphcore if you'd like assistance running model sizes that don't work in this simple example notebook.
#
# [![Join our Slack Community](https://img.shields.io/badge/Slack-Join%20Graphcore's%20Community-blue?style=flat-square&logo=slack)](https://www.graphcore.ai/join-community)

# %% [markdown]
# ## Environment setup
#
# In order to run this notebook you will need to be in an environment with the Poplar SDK installed and enabled. This is done by default on Paperspace. If you are not using Paperspace, refer to the [getting started guide](https://docs.graphcore.ai/en/latest/getting-started.html#getting-started) for your system for a description of how to set this up.
#
# We also need the Optimum Graphcore interface to the Hugging Face Transformers library, and there are a few extra dependencies we need to be able to handle audio.

# %% [markdown]
# In order to improve usability and support for future users, Graphcore would like to collect information about the
# applications and code being run in this notebook. The following information will be anonymised before being sent to Graphcore:
#
# - User progression through the notebook
# - Notebook details: number of cells, code being run and the output of the cells
# - Environment details
#
# You can disable logging at any time by running `%unload_ext gc_logger` from any cell.

# %%
# !pip install ipython==7.16.3 ipykernel==5.5.6
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cpu:
# Collecting ipython==7.16.3
#   Using cached ipython-7.16.3-py3-none-any.whl (783 kB)
# Collecting ipykernel==5.5.6
#   Using cached ipykernel-5.5.6-py3-none-any.whl (121 kB)
# Requirement already satisfied: setuptools>=18.5 in /opt/pytorch/lib/python3.8/site-packages (from ipython==7.16.3) (59.6.0)
# Requirement already satisfied: jedi<=0.17.2,>=0.10 in /opt/pytorch/lib/python3.8/site-packages (from ipython==7.16.3) (0.17.2)
# Requirement already satisfied: decorator in /opt/pytorch/lib/python3.8/site-packages (from ipython==7.16.3) (5.1.1)
# Requirement already satisfied: pickleshare in /opt/pytorch/lib/python3.8/site-packages (from ipython==7.16.3) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /opt/pytorch/lib/python3.8/site-packages (from ipython==7.16.3) (5.9.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/pytorch/lib/python3.8/site-packages (from ipython==7.16.3) (3.0.38)
# Requirement already satisfied: pygments in /opt/pytorch/lib/python3.8/site-packages (from ipython==7.16.3) (2.15.1)
# Requirement already satisfied: backcall in /opt/pytorch/lib/python3.8/site-packages (from ipython==7.16.3) (0.2.0)
# Requirement already satisfied: pexpect in /opt/pytorch/lib/python3.8/site-packages (from ipython==7.16.3) (4.8.0)
# Requirement already satisfied: ipython-genutils in /opt/pytorch/lib/python3.8/site-packages (from ipykernel==5.5.6) (0.2.0)
# Requirement already satisfied: jupyter-client in /opt/pytorch/lib/python3.8/site-packages (from ipykernel==5.5.6) (8.2.0)
# Requirement already satisfied: tornado>=4.2 in /opt/pytorch/lib/python3.8/site-packages (from ipykernel==5.5.6) (6.3.2)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /opt/pytorch/lib/python3.8/site-packages (from jedi<=0.17.2,>=0.10->ipython==7.16.3) (0.7.1)
# Requirement already satisfied: wcwidth in /opt/pytorch/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython==7.16.3) (0.2.6)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /opt/pytorch/lib/python3.8/site-packages (from jupyter-client->ipykernel==5.5.6) (6.7.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/pytorch/lib/python3.8/site-packages (from jupyter-client->ipykernel==5.5.6) (5.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/pytorch/lib/python3.8/site-packages (from jupyter-client->ipykernel==5.5.6) (2.8.2)
# Requirement already satisfied: pyzmq>=23.0 in /opt/pytorch/lib/python3.8/site-packages (from jupyter-client->ipykernel==5.5.6) (25.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/pytorch/lib/python3.8/site-packages (from pexpect->ipython==7.16.3) (0.7.0)
# Requirement already satisfied: zipp>=0.5 in /opt/pytorch/lib/python3.8/site-packages (from importlib-metadata>=4.8.3->jupyter-client->ipykernel==5.5.6) (3.15.0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/pytorch/lib/python3.8/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-client->ipykernel==5.5.6) (3.8.0)
# Requirement already satisfied: six>=1.5 in /opt/pytorch/lib/python3.8/site-packages (from python-dateutil>=2.8.2->jupyter-client->ipykernel==5.5.6) (1.16.0)
# Installing collected packages: ipython, ipykernel
#   Attempting uninstall: ipython
#     Found existing installation: ipython 8.12.2
#     Uninstalling ipython-8.12.2:
#       Successfully uninstalled ipython-8.12.2
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 6.23.3
#     Uninstalling ipykernel-6.23.3:
#       Successfully uninstalled ipykernel-6.23.3
# Successfully installed ipykernel-5.5.6 ipython-7.16.3

# %%
# !pip list
# Out:
# Package                  Version
# ------------------------ ------------
# accelerate               0.20.3
# agate                    1.7.1
# agate-dbf                0.2.2
# agate-excel              0.2.5
# agate-sql                0.5.9
# aiofiles                 22.1.0
# aiohttp                  3.8.4
# aiosignal                1.3.1
# aiosqlite                0.19.0
# anyio                    3.7.0
# appdirs                  1.4.4
# argon2-cffi              21.3.0
# argon2-cffi-bindings     21.2.0
# arrow                    1.2.3
# asttokens                2.2.1
# async-timeout            4.0.2
# attrs                    23.1.0
# audioread                3.0.0
# awscli                   1.27.163
# Babel                    2.12.1
# backcall                 0.2.0
# beautifulsoup4           4.12.2
# bleach                   6.0.0
# boto3                    1.26.163
# botocore                 1.29.163
# certifi                  2023.5.7
# cffi                     1.15.1
# charset-normalizer       3.1.0
# cmake                    3.26.3
# colorama                 0.4.4
# coloredlogs              15.0.1
# comm                     0.1.3
# cppimport                22.8.2
# csvkit                   1.1.1
# datasets                 2.13.1
# dbfread                  2.0.7
# debugpy                  1.6.7
# decorator                5.1.1
# defusedxml               0.7.1
# diffusers                0.12.1
# dill                     0.3.6
# distlib                  0.3.6
# docutils                 0.16
# et-xmlfile               1.1.0
# examples-utils           0.1.0
# exceptiongroup           1.1.1
# executing                1.2.0
# fastjsonschema           2.17.1
# filelock                 3.12.2
# fqdn                     1.5.1
# frozenlist               1.3.3
# fsspec                   2023.6.0
# gitdb                    4.0.10
# GitPython                3.1.31
# greenlet                 2.0.2
# huggingface-hub          0.15.1
# humanfriendly            10.0
# idna                     3.4
# importlib-metadata       6.7.0
# importlib-resources      5.12.0
# ipykernel                5.5.6
# ipynbname                2023.1.0.0
# ipython                  7.16.3
# ipython-genutils         0.2.0
# ipywidgets               8.0.6
# isodate                  0.6.1
# isoduration              20.11.0
# jedi                     0.17.2
# Jinja2                   3.1.2
# jmespath                 1.0.1
# joblib                   1.3.1
# json5                    0.9.14
# jsonpointer              2.4
# jsonschema               4.17.3
# jupyter                  1.0.0
# jupyter_client           8.2.0
# jupyter-console          6.4.4
# jupyter_core             5.3.0
# jupyter-events           0.6.3
# jupyter-server           1.24.0
# jupyter_server_fileid    0.9.0
# jupyter_server_terminals 0.4.4
# jupyter_server_ydoc      0.8.0
# jupyter-ydoc             0.2.4
# jupyterlab               3.2.7
# jupyterlab-pygments      0.2.2
# jupyterlab_server        2.22.1
# jupyterlab-widgets       3.0.7
# lazy_loader              0.2
# leather                  0.3.4
# librosa                  0.10.0.post2
# llvmlite                 0.40.1
# Mako                     1.2.4
# MarkupSafe               2.1.3
# matplotlib-inline        0.1.6
# mistune                  3.0.1
# mpmath                   1.3.0
# msgpack                  1.0.5
# multidict                6.0.4
# multiprocess             0.70.14
# mypy-extensions          1.0.0
# nbclassic                0.5.6
# nbclient                 0.8.0
# nbconvert                7.6.0
# nbformat                 5.9.0
# nest-asyncio             1.5.6
# networkx                 3.1
# notebook                 6.5.4
# notebook_shim            0.2.3
# numba                    0.57.1
# numpy                    1.21.6
# olefile                  0.46
# openpyxl                 3.1.2
# optimum                  1.6.1
# optimum-graphcore        0.6.1
# overrides                7.3.1
# packaging                23.1
# pandas                   2.0.3
# pandocfilters            1.5.0
# parsedatetime            2.6
# parso                    0.7.1
# pexpect                  4.8.0
# pickleshare              0.7.5
# Pillow                   9.5.0
# pip                      23.1.2
# pkg_resources            0.0.0
# pkgutil_resolve_name     1.3.10
# platformdirs             3.8.0
# pooch                    1.6.0
# poptorch                 3.3.0+113432
# prometheus-client        0.17.0
# prompt-toolkit           3.0.38
# protobuf                 3.20.2
# psutil                   5.9.5
# ptyprocess               0.7.0
# pure-eval                0.2.2
# pyarrow                  12.0.1
# pyasn1                   0.5.0
# pybind11                 2.10.4
# pycparser                2.21
# Pygments                 2.15.1
# pyrsistent               0.19.3
# python-dateutil          2.8.2
# python-json-logger       2.0.7
# python-slugify           8.0.1
# pytimeparse              1.1.8
# pytz                     2023.3
# PyYAML                   5.4.1
# pyzmq                    25.1.0
# qtconsole                5.4.3
# QtPy                     2.3.1
# regex                    2023.6.3
# requests                 2.31.0
# rfc3339-validator        0.1.4
# rfc3986-validator        0.1.1
# rsa                      4.7.2
# s3transfer               0.6.1
# scikit-learn             1.3.0
# scipy                    1.10.1
# Send2Trash               1.8.2
# sentencepiece            0.1.99
# setuptools               59.6.0
# simple-parsing           0.0.19.post1
# six                      1.16.0
# smmap                    5.0.0
# sniffio                  1.3.0
# soundfile                0.12.1
# soupsieve                2.4.1
# soxr                     0.3.5
# SQLAlchemy               1.4.48
# stack-data               0.6.2
# sympy                    1.12
# terminado                0.17.1
# text-unidecode           1.3
# threadpoolctl            3.1.0
# tinycss2                 1.2.1
# tokenizers               0.12.1
# tomli                    2.0.1
# torch                    2.0.1+cpu
# torchaudio               2.0.2+cpu
# torchvision              0.15.2+cpu
# tornado                  6.3.2
# tqdm                     4.65.0
# traitlets                5.9.0
# transformers             4.25.1
# typeguard                4.0.0
# typing_extensions        4.7.0
# typing-inspect           0.9.0
# tzdata                   2023.3
# uri-template             1.3.0
# urllib3                  1.26.16
# virtualenv               20.23.1
# wcwidth                  0.2.6
# webcolors                1.13
# webencodings             0.5.1
# websocket-client         1.6.1
# wheel                    0.40.0
# widgetsnbextension       4.0.7
# xlrd                     2.0.1
# xxhash                   3.2.0
# y-py                     0.5.9
# yarl                     1.9.2
# ypy-websocket            0.8.2
# zipp                     3.15.0

# %%
# %pip install "optimum-graphcore==0.6.1"
# %pip install soundfile==0.12.1 librosa==0.10.0.post2 tokenizers==0.12.1
# %pip install matplotlib
# %matplotlib inline
# %pip install examples-utils[common]@git+https://github.com/graphcore/examples-utils@latest_stable
# %load_ext examples_utils.notebook_logging.gc_logger
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cpu:
# Requirement already satisfied: optimum-graphcore==0.6.1 in /opt/pytorch/lib/python3.8/site-packages (0.6.1)
# Requirement already satisfied: transformers==4.25.1 in /opt/pytorch/lib/python3.8/site-packages (from optimum-graphcore==0.6.1) (4.25.1)
# Requirement already satisfied: optimum==1.6.1 in /opt/pytorch/lib/python3.8/site-packages (from optimum-graphcore==0.6.1) (1.6.1)
# Requirement already satisfied: diffusers[torch]==0.12.1 in /opt/pytorch/lib/python3.8/site-packages (from optimum-graphcore==0.6.1) (0.12.1)
# Requirement already satisfied: datasets in /opt/pytorch/lib/python3.8/site-packages (from optimum-graphcore==0.6.1) (2.13.1)
# Requirement already satisfied: tokenizers in /opt/pytorch/lib/python3.8/site-packages (from optimum-graphcore==0.6.1) (0.12.1)
# Requirement already satisfied: typeguard in /opt/pytorch/lib/python3.8/site-packages (from optimum-graphcore==0.6.1) (4.0.0)
# Requirement already satisfied: sentencepiece in /opt/pytorch/lib/python3.8/site-packages (from optimum-graphcore==0.6.1) (0.1.99)
# Requirement already satisfied: scipy in /opt/pytorch/lib/python3.8/site-packages (from optimum-graphcore==0.6.1) (1.10.1)
# Requirement already satisfied: pillow in /opt/pytorch/lib/python3.8/site-packages (from optimum-graphcore==0.6.1) (9.5.0)
# Requirement already satisfied: importlib-metadata in /opt/pytorch/lib/python3.8/site-packages (from diffusers[torch]==0.12.1->optimum-graphcore==0.6.1) (6.7.0)
# Requirement already satisfied: filelock in /opt/pytorch/lib/python3.8/site-packages (from diffusers[torch]==0.12.1->optimum-graphcore==0.6.1) (3.12.2)
# Requirement already satisfied: huggingface-hub>=0.10.0 in /opt/pytorch/lib/python3.8/site-packages (from diffusers[torch]==0.12.1->optimum-graphcore==0.6.1) (0.15.1)
# Requirement already satisfied: numpy in /opt/pytorch/lib/python3.8/site-packages (from diffusers[torch]==0.12.1->optimum-graphcore==0.6.1) (1.21.6)
# Requirement already satisfied: regex!=2019.12.17 in /opt/pytorch/lib/python3.8/site-packages (from diffusers[torch]==0.12.1->optimum-graphcore==0.6.1) (2023.6.3)
# Requirement already satisfied: requests in /opt/pytorch/lib/python3.8/site-packages (from diffusers[torch]==0.12.1->optimum-graphcore==0.6.1) (2.31.0)
# Requirement already satisfied: torch>=1.4 in /opt/pytorch/lib/python3.8/site-packages (from diffusers[torch]==0.12.1->optimum-graphcore==0.6.1) (2.0.1+cpu)
# Requirement already satisfied: accelerate>=0.11.0 in /opt/pytorch/lib/python3.8/site-packages (from diffusers[torch]==0.12.1->optimum-graphcore==0.6.1) (0.20.3)
# Requirement already satisfied: coloredlogs in /opt/pytorch/lib/python3.8/site-packages (from optimum==1.6.1->optimum-graphcore==0.6.1) (15.0.1)
# Requirement already satisfied: sympy in /opt/pytorch/lib/python3.8/site-packages (from optimum==1.6.1->optimum-graphcore==0.6.1) (1.12)
# Requirement already satisfied: packaging in /opt/pytorch/lib/python3.8/site-packages (from optimum==1.6.1->optimum-graphcore==0.6.1) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/pytorch/lib/python3.8/site-packages (from transformers==4.25.1->optimum-graphcore==0.6.1) (5.4.1)
# Requirement already satisfied: tqdm>=4.27 in /opt/pytorch/lib/python3.8/site-packages (from transformers==4.25.1->optimum-graphcore==0.6.1) (4.65.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /opt/pytorch/lib/python3.8/site-packages (from datasets->optimum-graphcore==0.6.1) (12.0.1)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /opt/pytorch/lib/python3.8/site-packages (from datasets->optimum-graphcore==0.6.1) (0.3.6)
# Requirement already satisfied: pandas in /opt/pytorch/lib/python3.8/site-packages (from datasets->optimum-graphcore==0.6.1) (2.0.3)
# Requirement already satisfied: xxhash in /opt/pytorch/lib/python3.8/site-packages (from datasets->optimum-graphcore==0.6.1) (3.2.0)
# Requirement already satisfied: multiprocess in /opt/pytorch/lib/python3.8/site-packages (from datasets->optimum-graphcore==0.6.1) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /opt/pytorch/lib/python3.8/site-packages (from datasets->optimum-graphcore==0.6.1) (2023.6.0)
# Requirement already satisfied: aiohttp in /opt/pytorch/lib/python3.8/site-packages (from datasets->optimum-graphcore==0.6.1) (3.8.4)
# Requirement already satisfied: typing-extensions>=4.4.0 in /opt/pytorch/lib/python3.8/site-packages (from typeguard->optimum-graphcore==0.6.1) (4.7.0)
# Requirement already satisfied: psutil in /opt/pytorch/lib/python3.8/site-packages (from accelerate>=0.11.0->diffusers[torch]==0.12.1->optimum-graphcore==0.6.1) (5.9.5)
# Requirement already satisfied: attrs>=17.3.0 in /opt/pytorch/lib/python3.8/site-packages (from aiohttp->datasets->optimum-graphcore==0.6.1) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/pytorch/lib/python3.8/site-packages (from aiohttp->datasets->optimum-graphcore==0.6.1) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/pytorch/lib/python3.8/site-packages (from aiohttp->datasets->optimum-graphcore==0.6.1) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/pytorch/lib/python3.8/site-packages (from aiohttp->datasets->optimum-graphcore==0.6.1) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/pytorch/lib/python3.8/site-packages (from aiohttp->datasets->optimum-graphcore==0.6.1) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/pytorch/lib/python3.8/site-packages (from aiohttp->datasets->optimum-graphcore==0.6.1) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/pytorch/lib/python3.8/site-packages (from aiohttp->datasets->optimum-graphcore==0.6.1) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /opt/pytorch/lib/python3.8/site-packages (from importlib-metadata->diffusers[torch]==0.12.1->optimum-graphcore==0.6.1) (3.15.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/pytorch/lib/python3.8/site-packages (from requests->diffusers[torch]==0.12.1->optimum-graphcore==0.6.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/pytorch/lib/python3.8/site-packages (from requests->diffusers[torch]==0.12.1->optimum-graphcore==0.6.1) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/pytorch/lib/python3.8/site-packages (from requests->diffusers[torch]==0.12.1->optimum-graphcore==0.6.1) (2023.5.7)
# Requirement already satisfied: networkx in /opt/pytorch/lib/python3.8/site-packages (from torch>=1.4->diffusers[torch]==0.12.1->optimum-graphcore==0.6.1) (3.1)
# Requirement already satisfied: jinja2 in /opt/pytorch/lib/python3.8/site-packages (from torch>=1.4->diffusers[torch]==0.12.1->optimum-graphcore==0.6.1) (3.1.2)
# Requirement already satisfied: protobuf<=3.20.2 in /opt/pytorch/lib/python3.8/site-packages (from transformers==4.25.1->optimum-graphcore==0.6.1) (3.20.2)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/pytorch/lib/python3.8/site-packages (from coloredlogs->optimum==1.6.1->optimum-graphcore==0.6.1) (10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/pytorch/lib/python3.8/site-packages (from pandas->datasets->optimum-graphcore==0.6.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/pytorch/lib/python3.8/site-packages (from pandas->datasets->optimum-graphcore==0.6.1) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/pytorch/lib/python3.8/site-packages (from pandas->datasets->optimum-graphcore==0.6.1) (2023.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/pytorch/lib/python3.8/site-packages (from sympy->optimum==1.6.1->optimum-graphcore==0.6.1) (1.3.0)
# Requirement already satisfied: six>=1.5 in /opt/pytorch/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas->datasets->optimum-graphcore==0.6.1) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/pytorch/lib/python3.8/site-packages (from jinja2->torch>=1.4->diffusers[torch]==0.12.1->optimum-graphcore==0.6.1) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cpu:
# Requirement already satisfied: soundfile==0.12.1 in /opt/pytorch/lib/python3.8/site-packages (0.12.1)
# Requirement already satisfied: librosa==0.10.0.post2 in /opt/pytorch/lib/python3.8/site-packages (0.10.0.post2)
# Requirement already satisfied: tokenizers==0.12.1 in /opt/pytorch/lib/python3.8/site-packages (0.12.1)
# Requirement already satisfied: cffi>=1.0 in /opt/pytorch/lib/python3.8/site-packages (from soundfile==0.12.1) (1.15.1)
# Requirement already satisfied: audioread>=2.1.9 in /opt/pytorch/lib/python3.8/site-packages (from librosa==0.10.0.post2) (3.0.0)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /opt/pytorch/lib/python3.8/site-packages (from librosa==0.10.0.post2) (1.21.6)
# Requirement already satisfied: scipy>=1.2.0 in /opt/pytorch/lib/python3.8/site-packages (from librosa==0.10.0.post2) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/pytorch/lib/python3.8/site-packages (from librosa==0.10.0.post2) (1.3.0)
# Requirement already satisfied: joblib>=0.14 in /opt/pytorch/lib/python3.8/site-packages (from librosa==0.10.0.post2) (1.3.1)
# Requirement already satisfied: decorator>=4.3.0 in /opt/pytorch/lib/python3.8/site-packages (from librosa==0.10.0.post2) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /opt/pytorch/lib/python3.8/site-packages (from librosa==0.10.0.post2) (0.57.1)
# Requirement already satisfied: pooch<1.7,>=1.0 in /opt/pytorch/lib/python3.8/site-packages (from librosa==0.10.0.post2) (1.6.0)
# Requirement already satisfied: soxr>=0.3.2 in /opt/pytorch/lib/python3.8/site-packages (from librosa==0.10.0.post2) (0.3.5)
# Requirement already satisfied: typing-extensions>=4.1.1 in /opt/pytorch/lib/python3.8/site-packages (from librosa==0.10.0.post2) (4.7.0)
# Requirement already satisfied: lazy-loader>=0.1 in /opt/pytorch/lib/python3.8/site-packages (from librosa==0.10.0.post2) (0.2)
# Requirement already satisfied: msgpack>=1.0 in /opt/pytorch/lib/python3.8/site-packages (from librosa==0.10.0.post2) (1.0.5)
# Requirement already satisfied: pycparser in /opt/pytorch/lib/python3.8/site-packages (from cffi>=1.0->soundfile==0.12.1) (2.21)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /opt/pytorch/lib/python3.8/site-packages (from numba>=0.51.0->librosa==0.10.0.post2) (0.40.1)
# Requirement already satisfied: importlib-metadata in /opt/pytorch/lib/python3.8/site-packages (from numba>=0.51.0->librosa==0.10.0.post2) (6.7.0)
# Requirement already satisfied: appdirs>=1.3.0 in /opt/pytorch/lib/python3.8/site-packages (from pooch<1.7,>=1.0->librosa==0.10.0.post2) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/pytorch/lib/python3.8/site-packages (from pooch<1.7,>=1.0->librosa==0.10.0.post2) (23.1)
# Requirement already satisfied: requests>=2.19.0 in /opt/pytorch/lib/python3.8/site-packages (from pooch<1.7,>=1.0->librosa==0.10.0.post2) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/pytorch/lib/python3.8/site-packages (from scikit-learn>=0.20.0->librosa==0.10.0.post2) (3.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/pytorch/lib/python3.8/site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa==0.10.0.post2) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/pytorch/lib/python3.8/site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa==0.10.0.post2) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/pytorch/lib/python3.8/site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa==0.10.0.post2) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/pytorch/lib/python3.8/site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa==0.10.0.post2) (2023.5.7)
# Requirement already satisfied: zipp>=0.5 in /opt/pytorch/lib/python3.8/site-packages (from importlib-metadata->numba>=0.51.0->librosa==0.10.0.post2) (3.15.0)
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cpu:
# Collecting examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable
#   Cloning https://github.com/graphcore/examples-utils (to revision latest_stable) to /tmp/pip-install-7ysp3daj/examples-utils_def49af3cf634b77bd06d6888f0fb65e
#   Running command git clone --filter=blob:none --quiet https://github.com/graphcore/examples-utils /tmp/pip-install-7ysp3daj/examples-utils_def49af3cf634b77bd06d6888f0fb65e
#   Running command git checkout -q 40c62e6646db8f9d60d1707a61204c95a15c7ccb
#   Resolved https://github.com/graphcore/examples-utils to commit 40c62e6646db8f9d60d1707a61204c95a15c7ccb
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: awscli>=1.24.10 in /opt/pytorch/lib/python3.8/site-packages (from examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (1.27.163)
# Requirement already satisfied: boto3>=1.26 in /opt/pytorch/lib/python3.8/site-packages (from examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (1.26.163)
# Requirement already satisfied: cppimport>=22.07.17 in /opt/pytorch/lib/python3.8/site-packages (from examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (22.8.2)
# Requirement already satisfied: filelock>=3.9.0 in /opt/pytorch/lib/python3.8/site-packages (from examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (3.12.2)
# Requirement already satisfied: gitpython>=3.1 in /opt/pytorch/lib/python3.8/site-packages (from examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (3.1.31)
# Requirement already satisfied: ipynbname>=2021.3.2 in /opt/pytorch/lib/python3.8/site-packages (from examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (2023.1.0.0)
# Requirement already satisfied: nbformat>=5.7.3 in /opt/pytorch/lib/python3.8/site-packages (from examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (5.9.0)
# Requirement already satisfied: psutil>=5.7.0 in /opt/pytorch/lib/python3.8/site-packages (from examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (5.9.5)
# Requirement already satisfied: pyyaml>=5.4.1 in /opt/pytorch/lib/python3.8/site-packages (from examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (5.4.1)
# Requirement already satisfied: simple-parsing==0.0.19.post1 in /opt/pytorch/lib/python3.8/site-packages (from examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (0.0.19.post1)
# Requirement already satisfied: typing-inspect in /opt/pytorch/lib/python3.8/site-packages (from simple-parsing==0.0.19.post1->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (0.9.0)
# Requirement already satisfied: botocore==1.29.163 in /opt/pytorch/lib/python3.8/site-packages (from awscli>=1.24.10->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (1.29.163)
# Requirement already satisfied: docutils<0.17,>=0.10 in /opt/pytorch/lib/python3.8/site-packages (from awscli>=1.24.10->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (0.16)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /opt/pytorch/lib/python3.8/site-packages (from awscli>=1.24.10->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (0.6.1)
# Requirement already satisfied: colorama<0.4.5,>=0.2.5 in /opt/pytorch/lib/python3.8/site-packages (from awscli>=1.24.10->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (0.4.4)
# Requirement already satisfied: rsa<4.8,>=3.1.2 in /opt/pytorch/lib/python3.8/site-packages (from awscli>=1.24.10->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (4.7.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/pytorch/lib/python3.8/site-packages (from botocore==1.29.163->awscli>=1.24.10->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/pytorch/lib/python3.8/site-packages (from botocore==1.29.163->awscli>=1.24.10->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /opt/pytorch/lib/python3.8/site-packages (from botocore==1.29.163->awscli>=1.24.10->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (1.26.16)
# Requirement already satisfied: mako in /opt/pytorch/lib/python3.8/site-packages (from cppimport>=22.07.17->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (1.2.4)
# Requirement already satisfied: pybind11 in /opt/pytorch/lib/python3.8/site-packages (from cppimport>=22.07.17->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (2.10.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/pytorch/lib/python3.8/site-packages (from gitpython>=3.1->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (4.0.10)
# Requirement already satisfied: ipykernel in /opt/pytorch/lib/python3.8/site-packages (from ipynbname>=2021.3.2->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (5.5.6)
# Requirement already satisfied: fastjsonschema in /opt/pytorch/lib/python3.8/site-packages (from nbformat>=5.7.3->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (2.17.1)
# Requirement already satisfied: jsonschema>=2.6 in /opt/pytorch/lib/python3.8/site-packages (from nbformat>=5.7.3->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (4.17.3)
# Requirement already satisfied: jupyter-core in /opt/pytorch/lib/python3.8/site-packages (from nbformat>=5.7.3->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (5.3.0)
# Requirement already satisfied: traitlets>=5.1 in /opt/pytorch/lib/python3.8/site-packages (from nbformat>=5.7.3->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (5.9.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/pytorch/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (5.0.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/pytorch/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.7.3->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (23.1.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /opt/pytorch/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.7.3->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (5.12.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /opt/pytorch/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.7.3->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (1.3.10)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/pytorch/lib/python3.8/site-packages (from jsonschema>=2.6->nbformat>=5.7.3->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (0.19.3)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/pytorch/lib/python3.8/site-packages (from rsa<4.8,>=3.1.2->awscli>=1.24.10->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (0.5.0)
# Requirement already satisfied: ipython-genutils in /opt/pytorch/lib/python3.8/site-packages (from ipykernel->ipynbname>=2021.3.2->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (0.2.0)
# Requirement already satisfied: ipython>=5.0.0 in /opt/pytorch/lib/python3.8/site-packages (from ipykernel->ipynbname>=2021.3.2->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (7.16.3)
# Requirement already satisfied: jupyter-client in /opt/pytorch/lib/python3.8/site-packages (from ipykernel->ipynbname>=2021.3.2->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (8.2.0)
# Requirement already satisfied: tornado>=4.2 in /opt/pytorch/lib/python3.8/site-packages (from ipykernel->ipynbname>=2021.3.2->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (6.3.2)
# Requirement already satisfied: platformdirs>=2.5 in /opt/pytorch/lib/python3.8/site-packages (from jupyter-core->nbformat>=5.7.3->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (3.8.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /opt/pytorch/lib/python3.8/site-packages (from mako->cppimport>=22.07.17->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (2.1.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/pytorch/lib/python3.8/site-packages (from typing-inspect->simple-parsing==0.0.19.post1->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (1.0.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /opt/pytorch/lib/python3.8/site-packages (from typing-inspect->simple-parsing==0.0.19.post1->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (4.7.0)
# Requirement already satisfied: zipp>=3.1.0 in /opt/pytorch/lib/python3.8/site-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat>=5.7.3->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (3.15.0)
# Requirement already satisfied: setuptools>=18.5 in /opt/pytorch/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->ipynbname>=2021.3.2->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (59.6.0)
# Requirement already satisfied: jedi<=0.17.2,>=0.10 in /opt/pytorch/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->ipynbname>=2021.3.2->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (0.17.2)
# Requirement already satisfied: decorator in /opt/pytorch/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->ipynbname>=2021.3.2->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (5.1.1)
# Requirement already satisfied: pickleshare in /opt/pytorch/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->ipynbname>=2021.3.2->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/pytorch/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->ipynbname>=2021.3.2->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (3.0.38)
# Requirement already satisfied: pygments in /opt/pytorch/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->ipynbname>=2021.3.2->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (2.15.1)
# Requirement already satisfied: backcall in /opt/pytorch/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->ipynbname>=2021.3.2->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (0.2.0)
# Requirement already satisfied: pexpect in /opt/pytorch/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel->ipynbname>=2021.3.2->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (4.8.0)
# Requirement already satisfied: six>=1.5 in /opt/pytorch/lib/python3.8/site-packages (from python-dateutil<3.0.0,>=2.1->botocore==1.29.163->awscli>=1.24.10->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (1.16.0)
# Requirement already satisfied: importlib-metadata>=4.8.3 in /opt/pytorch/lib/python3.8/site-packages (from jupyter-client->ipykernel->ipynbname>=2021.3.2->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (6.7.0)
# Requirement already satisfied: pyzmq>=23.0 in /opt/pytorch/lib/python3.8/site-packages (from jupyter-client->ipykernel->ipynbname>=2021.3.2->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (25.1.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /opt/pytorch/lib/python3.8/site-packages (from jedi<=0.17.2,>=0.10->ipython>=5.0.0->ipykernel->ipynbname>=2021.3.2->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (0.7.1)
# Requirement already satisfied: wcwidth in /opt/pytorch/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->ipynbname>=2021.3.2->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (0.2.6)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/pytorch/lib/python3.8/site-packages (from pexpect->ipython>=5.0.0->ipykernel->ipynbname>=2021.3.2->examples-utils[common]@ git+https://github.com/graphcore/examples-utils@latest_stable) (0.7.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Running Whisper on the IPU
#
# We start by importing the required modules, some of which are needed to configure the IPU.

# %%
import os
os.environ["POPART_LOG_LEVEL"] = "INFO"
os.environ["POPLAR_LOG_LEVEL"] = "INFO"

# %%
# Generic imports
from datasets import load_dataset
# import matplotlib
# import librosa
# import IPython
# import random

# IPU-specific imports
from optimum.graphcore import IPUConfig
from optimum.graphcore.modeling_utils import to_pipelined

# HF-related imports
from transformers import WhisperProcessor, WhisperForConditionalGeneration

# %% [markdown]
# The Whisper model is available on Hugging Face in several sizes, from `whisper-tiny` with 39M parameters to `whisper-large` with 1550M parameters.
#
# We download `whisper-tiny` which we will run using two IPUs.
# The [Whisper architecture](https://openai.com/research/whisper) is an encoder-decoder Transformer, with the audio split into 30-second chunks.
# For simplicity one IPU is used for the encoder part of the graph and another for the decoder part.
# The `IPUConfig` object helps to configure the model to be pipelined across the IPUs.

# %%
model_spec = "openai/whisper-tiny.en"

# Instantiate processor and model
processor = WhisperProcessor.from_pretrained(model_spec)
model = WhisperForConditionalGeneration.from_pretrained(model_spec)

# Adapt whisper-tiny to run on the IPU
ipu_config = IPUConfig(ipus_per_replica=2)
pipelined_model = to_pipelined(model, ipu_config)
pipelined_model = pipelined_model.parallelize(for_generation=True).half()

# %% [markdown]
# Now we can load the dataset and process an example audio file.
# If precompiled models are not available, then the first run of the model triggers two graph compilations.
# This means that our first test transcription could take a minute or two to run, but subsequent runs will be much faster.

# %%
# load the dataset and read an example sound file
ds = load_dataset("hf-internal-testing/librispeech_asr_dummy", "clean", split="validation")
test_sample = ds[2]
sample_rate = test_sample['audio']['sampling_rate']
# Out:
# Found cached dataset librispeech_asr_dummy (/tmp/huggingface_caches/datasets/hf-internal-testing___librispeech_asr_dummy/clean/2.1.0/d3bc4c2bc2078fcde3ad0f0f635862e4c0fef78ba94c4a34c4c250a097af240b)

# %%
def transcribe(data, rate):
    input_features = processor(data, return_tensors="pt", sampling_rate=rate).input_features.half()

    # This triggers a compilation, unless a precompiled model is available.
    sample_output = pipelined_model.generate(input_features, max_length=448, min_length=3)
    transcription = processor.batch_decode(sample_output, skip_special_tokens=True)[0]
    return transcription

# %%
test_transcription = transcribe(test_sample["audio"]["array"], sample_rate)
# Out:
# 2023-06-30T13:38:56.603301Z popart:pattern 1225.1225 I: Pattern TiedGather 1
# 2023-06-30T13:38:56.603335Z popart:pattern 1225.1225 I: Pattern TiedGatherAccumulate 1
# 2023-06-30T13:38:56.645276Z popart:builder 1225.1225 I: Setting domain '' to opset version 11
# 2023-06-30T13:38:56.649238Z popart:builder 1225.1225 I: Setting domain 'ai.graphcore' to opset version 1
# 2023-06-30T13:38:56.652433Z popart:builder 1225.1225 I: Warning: no inferred shape for output 0/self_attn/Constant:0 of ai.onnx.Constant:11. This will likely cause shape inference of subsequent ops to fail and prevent shape information being available from the builder.
# 2023-06-30T13:38:57.292347Z popart:session 1225.1225 I: Popart version: 3.3.0+7857 (b88fd7c399)
# 2023-06-30T13:38:57.292367Z popart:session 1225.1225 I: Popart release githash: b67b751185
# Graph compilation:   0%|          | 0/100 [00:00<?]2023-06-30T13:38:57.295811Z popart:popart 1225.1225 I: Onnx Model Info ir_version:4, producer:., domain:"", model_version:0 num_opsets:2
# 2023-06-30T13:38:57.295822Z popart:popart 1225.1225 I: Onnx Model OpSet domain:"" version:11
# 2023-06-30T13:38:57.295825Z popart:popart 1225.1225 I: Onnx Model OpSet domain:"ai.graphcore" version:1
# 2023-06-30T13:38:57.295831Z popart:popart 1225.1225 I: Onnx Graph Info name:"BuilderGraph_0" num_nodes:352 num_initializers:67 num_inputs:68 num_outputs:0 num_value_infos:370
# 2023-06-30T13:38:57.295908Z popart:session 1225.1225 I: PopEF file inferred to have hash '4961678486983961202' has been found: /tmp/exe_cache/3.3.0/4961678486983961202.popef
# 2023-06-30T13:38:57.295949Z popart:devicex 1225.1225 I: Setting engine options for prefetch data streams (exchange.streamBufferOverlap = hostRearrangeOnly, exchange.enablePrefetch = true
# 2023-06-30T13:38:57.295958Z popart:devicex 1225.1225 I: Setting engine option debug.retainDebugInformation = false
# 2023-06-30T13:38:57.295965Z popart:devicex 1225.1225 I: Setting engine option opt.useAutoloader = true
# 2023-06-30T13:38:57.295969Z popart:devicex 1225.1225 I: Setting engine option target.syncReplicasIndependently = true
# 2023-06-30T13:38:57.296140Z PO:ENGINE   1225.1225 I: Poplar Engine Options are clear
# 2023-06-30T13:38:57.296366Z popart:pattern 1225.1225 I: Enabling default patterns
# 2023-06-30T13:38:57.298387Z popart:popart 1225.1225 I: Adding Variable Tensor conv1.weight to Ir with consumers [ Conv@1 ].
# 2023-06-30T13:38:57.298661Z popart:popart 1225.1225 I: Adding Variable Tensor conv1.bias to Ir with consumers [ Conv@2 ].
# 2023-06-30T13:38:57.298700Z popart:popart 1225.1225 I: Adding Variable Tensor conv2.weight to Ir with consumers [ Conv@1 ].
# 2023-06-30T13:38:57.299454Z popart:popart 1225.1225 I: Adding Variable Tensor conv2.bias to Ir with consumers [ Conv@2 ].
# 2023-06-30T13:38:57.299497Z popart:popart 1225.1225 I: Adding Variable Tensor embed_positions.weight to Ir with consumers [ Add@1 ].
# 2023-06-30T13:38:57.300119Z popart:popart 1225.1225 I: Adding Variable Tensor layers.0.self_attn.k_proj.weight to Ir with consumers [ Transpose@0 ].
# 2023-06-30T13:38:57.300320Z popart:popart 1225.1225 I: Adding Variable Tensor layers.0.self_attn.v_proj.weight to Ir with consumers [ Transpose@0 ].
# 2023-06-30T13:38:57.300496Z popart:popart 1225.1225 I: Adding Variable Tensor layers.0.self_attn.v_proj.bias to Ir with consumers [ Gemm@2 ].
# 2023-06-30T13:38:57.300540Z popart:popart 1225.1225 I: Adding Variable Tensor layers.0.self_attn.q_proj.weight to Ir with consumers [ Transpose@0 ].
# 2023-06-30T13:38:57.300798Z popart:popart 1225.1225 I: Adding Variable Tensor layers.0.self_attn.q_proj.bias to Ir with consumers [ Gemm@2 ].
# 2023-06-30T13:38:57.300844Z popart:popart 1225.1225 I: Adding Variable Tensor layers.0.self_attn.out_proj.weight to Ir with consumers [ Transpose@0 ].
# 2023-06-30T13:38:57.301039Z popart:popart 1225.1225 I: Adding Variable Tensor layers.0.self_attn.out_proj.bias to Ir with consumers [ Gemm@2 ].
# 2023-06-30T13:38:57.301087Z popart:popart 1225.1225 I: Adding Variable Tensor layers.0.self_attn_layer_norm.weight to Ir with consumers [ Reshape@0 ].
# 2023-06-30T13:38:57.301135Z popart:popart 1225.1225 I: Adding Variable Tensor layers.0.self_attn_layer_norm.bias to Ir with consumers [ Reshape@0 ].
# 2023-06-30T13:38:57.301190Z popart:popart 1225.1225 I: Adding Variable Tensor layers.0.fc1.weight to Ir with consumers [ Transpose@0 ].
# 2023-06-30T13:38:57.301850Z popart:popart 1225.1225 I: Adding Variable Tensor layers.0.fc1.bias to Ir with consumers [ Gemm@2 ].
# 2023-06-30T13:38:57.301905Z popart:popart 1225.1225 I: Adding Variable Tensor layers.0.fc2.weight to Ir with consumers [ Transpose@0 ].
# 2023-06-30T13:38:57.302524Z popart:popart 1225.1225 I: Adding Variable Tensor layers.0.fc2.bias to Ir with consumers [ Gemm@2 ].
# 2023-06-30T13:38:57.302581Z popart:popart 1225.1225 I: Adding Variable Tensor layers.0.final_layer_norm.weight to Ir with consumers [ Reshape@0 ].
# 2023-06-30T13:38:57.302635Z popart:popart 1225.1225 I: Adding Variable Tensor layers.0.final_layer_norm.bias to Ir with consumers [ Reshape@0 ].
# 2023-06-30T13:38:57.302689Z popart:popart 1225.1225 I: Adding Variable Tensor layers.1.self_attn.k_proj.weight to Ir with consumers [ Transpose@0 ].
# 2023-06-30T13:38:57.302894Z popart:popart 1225.1225 I: Adding Variable Tensor layers.1.self_attn.v_proj.weight to Ir with consumers [ Transpose@0 ].
# 2023-06-30T13:38:57.303186Z popart:popart 1225.1225 I: Adding Variable Tensor layers.1.self_attn.v_proj.bias to Ir with consumers [ Gemm@2 ].
# 2023-06-30T13:38:57.303244Z popart:popart 1225.1225 I: Adding Variable Tensor layers.1.self_attn.q_proj.weight to Ir with consumers [ Transpose@0 ].
# 2023-06-30T13:38:57.303455Z popart:popart 1225.1225 I: Adding Variable Tensor layers.1.self_attn.q_proj.bias to Ir with consumers [ Gemm@2 ].
# 2023-06-30T13:38:57.303516Z popart:popart 1225.1225 I: Adding Variable Tensor layers.1.self_attn.out_proj.weight to Ir with consumers [ Transpose@0 ].
# 2023-06-30T13:38:57.303722Z popart:popart 1225.1225 I: Adding Variable Tensor layers.1.self_attn.out_proj.bias to Ir with consumers [ Gemm@2 ].
# 2023-06-30T13:38:57.303783Z popart:popart 1225.1225 I: Adding Variable Tensor layers.1.self_attn_layer_norm.weight to Ir with consumers [ Reshape@0 ].
# 2023-06-30T13:38:57.303849Z popart:popart 1225.1225 I: Adding Variable Tensor layers.1.self_attn_layer_norm.bias to Ir with consumers [ Reshape@0 ].
# 2023-06-30T13:38:57.303912Z popart:popart 1225.1225 I: Adding Variable Tensor layers.1.fc1.weight to Ir with consumers [ Transpose@0 ].
# 2023-06-30T13:38:57.304590Z popart:popart 1225.1225 I: Adding Variable Tensor layers.1.fc1.bias to Ir with consumers [ Gemm@2 ].
# 2023-06-30T13:38:57.304661Z popart:popart 1225.1225 I: Adding Variable Tensor layers.1.fc2.weight to Ir with consumers [ Transpose@0 ].
# 2023-06-30T13:38:57.305352Z popart:popart 1225.1225 I: Adding Variable Tensor layers.1.fc2.bias to Ir with consumers [ Gemm@2 ].
# 2023-06-30T13:38:57.305422Z popart:popart 1225.1225 I: Adding Variable Tensor layers.1.final_layer_norm.weight to Ir with consumers [ Reshape@0 ].
# 2023-06-30T13:38:57.305494Z popart:popart 1225.1225 I: Adding Variable Tensor layers.1.final_layer_norm.bias to Ir with consumers [ Reshape@0 ].
# 2023-06-30T13:38:57.305564Z popart:popart 1225.1225 I: Adding Variable Tensor layers.2.self_attn.k_proj.weight to Ir with consumers [ Transpose@0 ].
# 2023-06-30T13:38:57.305873Z popart:popart 1225.1225 I: Adding Variable Tensor layers.2.self_attn.v_proj.weight to Ir with consumers [ Transpose@0 ].
# 2023-06-30T13:38:57.306120Z popart:popart 1225.1225 I: Adding Variable Tensor layers.2.self_attn.v_proj.bias to Ir with consumers [ Gemm@2 ].
# 2023-06-30T13:38:57.306198Z popart:popart 1225.1225 I: Adding Variable Tensor layers.2.self_attn.q_proj.weight to Ir with consumers [ Transpose@0 ].
# 2023-06-30T13:38:57.306453Z popart:popart 1225.1225 I: Adding Variable Tensor layers.2.self_attn.q_proj.bias to Ir with consumers [ Gemm@2 ].
# 2023-06-30T13:38:57.306533Z popart:popart 1225.1225 I: Adding Variable Tensor layers.2.self_attn.out_proj.weight to Ir with consumers [ Transpose@0 ].
# 2023-06-30T13:38:57.306831Z popart:popart 1225.1225 I: Adding Variable Tensor layers.2.self_attn.out_proj.bias to Ir with consumers [ Gemm@2 ].
# 2023-06-30T13:38:57.306912Z popart:popart 1225.1225 I: Adding Variable Tensor layers.2.self_attn_layer_norm.weight to Ir with consumers [ Reshape@0 ].
# 2023-06-30T13:38:57.306996Z popart:popart 1225.1225 I: Adding Variable Tensor layers.2.self_attn_layer_norm.bias to Ir with consumers [ Reshape@0 ].
# 2023-06-30T13:38:57.307072Z popart:popart 1225.1225 I: Adding Variable Tensor layers.2.fc1.weight to Ir with consumers [ Transpose@0 ].
# 2023-06-30T13:38:57.307751Z popart:popart 1225.1225 I: Adding Variable Tensor layers.2.fc1.bias to Ir with consumers [ Gemm@2 ].
# 2023-06-30T13:38:57.307838Z popart:popart 1225.1225 I: Adding Variable Tensor layers.2.fc2.weight to Ir with consumers [ Transpose@0 ].
# 2023-06-30T13:38:57.308486Z popart:popart 1225.1225 I: Adding Variable Tensor layers.2.fc2.bias to Ir with consumers [ Gemm@2 ].
# 2023-06-30T13:38:57.308574Z popart:popart 1225.1225 I: Adding Variable Tensor layers.2.final_layer_norm.weight to Ir with consumers [ Reshape@0 ].
# 2023-06-30T13:38:57.308660Z popart:popart 1225.1225 I: Adding Variable Tensor layers.2.final_layer_norm.bias to Ir with consumers [ Reshape@0 ].
# 2023-06-30T13:38:57.308747Z popart:popart 1225.1225 I: Adding Variable Tensor layers.3.self_attn.k_proj.weight to Ir with consumers [ Transpose@0 ].
# 2023-06-30T13:38:57.308990Z popart:popart 1225.1225 I: Adding Variable Tensor layers.3.self_attn.v_proj.weight to Ir with consumers [ Transpose@0 ].
# 2023-06-30T13:38:57.309215Z popart:popart 1225.1225 I: Adding Variable Tensor layers.3.self_attn.v_proj.bias to Ir with consumers [ Gemm@2 ].
# 2023-06-30T13:38:57.309307Z popart:popart 1225.1225 I: Adding Variable Tensor layers.3.self_attn.q_proj.weight to Ir with consumers [ Transpose@0 ].
# 2023-06-30T13:38:57.309613Z popart:popart 1225.1225 I: Adding Variable Tensor layers.3.self_attn.q_proj.bias to Ir with consumers [ Gemm@2 ].
# 2023-06-30T13:38:57.309709Z popart:popart 1225.1225 I: Adding Variable Tensor layers.3.self_attn.out_proj.weight to Ir with consumers [ Transpose@0 ].
# 2023-06-30T13:38:57.309930Z popart:popart 1225.1225 I: Adding Variable Tensor layers.3.self_attn.out_proj.bias to Ir with consumers [ Gemm@2 ].
# 2023-06-30T13:38:57.310027Z popart:popart 1225.1225 I: Adding Variable Tensor layers.3.self_attn_layer_norm.weight to Ir with consumers [ Reshape@0 ].
# 2023-06-30T13:38:57.310123Z popart:popart 1225.1225 I: Adding Variable Tensor layers.3.self_attn_layer_norm.bias to Ir with consumers [ Reshape@0 ].
# 2023-06-30T13:38:57.310217Z popart:popart 1225.1225 I: Adding Variable Tensor layers.3.fc1.weight to Ir with consumers [ Transpose@0 ].
# 2023-06-30T13:38:57.310967Z popart:popart 1225.1225 I: Adding Variable Tensor layers.3.fc1.bias to Ir with consumers [ Gemm@2 ].
# 2023-06-30T13:38:57.311073Z popart:popart 1225.1225 I: Adding Variable Tensor layers.3.fc2.weight to Ir with consumers [ Transpose@0 ].
# 2023-06-30T13:38:57.311800Z popart:popart 1225.1225 I: Adding Variable Tensor layers.3.fc2.bias to Ir with consumers [ Gemm@2 ].
# 2023-06-30T13:38:57.311915Z popart:popart 1225.1225 I: Adding Variable Tensor layers.3.final_layer_norm.weight to Ir with consumers [ Reshape@0 ].
# 2023-06-30T13:38:57.312018Z popart:popart 1225.1225 I: Adding Variable Tensor layers.3.final_layer_norm.bias to Ir with consumers [ Reshape@0 ].
# 2023-06-30T13:38:57.312118Z popart:popart 1225.1225 I: Adding Variable Tensor layer_norm.weight to Ir with consumers [ Reshape@0 ].
# 2023-06-30T13:38:57.312221Z popart:popart 1225.1225 I: Adding Variable Tensor layer_norm.bias to Ir with consumers [ Reshape@0 ].
# 2023-06-30T13:38:57.312270Z popart:popart 1225.1225 I: Adding Stream Tensor input to Ir with consumers [ Conv@0 ].
# 2023-06-30T13:38:57.312470Z popart:ir 1225.1225 I: Patterns : PreUniRepl LSTMOp Slice2SliceSubsample CoshOp MatMulOp PadSum ZerosLikeOpPattern RandomNormalLikeOpPattern RandomUniformLikeOpPattern SplitOp SumToAdd CosGradOp ExpGradOp LogGradOp ExpandCast ScanToLoop SoftmaxGradDirect SqrtGradOp TiedGather Expm1GradOp Log1pGradOp LoopScanOut SplitGather ConvDataGrad MulArgGradOp OpToIdentity ConvTranspose DivArg0GradOp DivArg1GradOp MatMulLhsGradOp MatMulRhsGradOp PowArg0GradOp PowArg1GradOp FmodArg0GradOp InitAccumulate Atan2Arg0GradOp Atan2Arg1GradOp PackedDataBlock NegativeOneScale ReciprocalGradOp UpsampleToResize AbsGradOp SinGradOp NlllWithSoftmaxGradDirect SubtractArg1GradOp AllReduceToIdentity DecomposeBinaryConstScalar SplitGradOpToConcat LambSerialisedWeight TiedGatherAccumulate ConvFlipWeightsGradOp RemoveUnnecessaryLossGradCast ConvFlipWeightsDoubleFlip TransposeToIdentityOrReshapePattern PostNRepl
# 2023-06-30T13:38:57.377339Z popart:session 1225.1225 I: PopART cache file has been found: /tmp/exe_cache/3.3.0/4961678486983961202.popef
# 2023-06-30T13:38:57.377404Z popart:ir 1225.1225 I: Ir hash matched cached value. Skipping Ir preparation
# 2023-06-30T13:38:57.384318Z popart:session 1225.1225 I: Loading serialized PopART executable from /tmp/exe_cache/3.3.0/4961678486983961202.popef
# 2023-06-30T13:38:57.387765Z PO:TARGET   1225.1225 I: Deserializing executable
# 2023-06-30T13:38:57.387794Z PO:TARGET   1225.1225 I: Reading Graphcore binary of 358612048 bytes
# 2023-06-30T13:38:57.387837Z PO:UTIL     1225.1225 I: Using temp directory '/tmp/'
# 2023-06-30T13:38:57.806518Z PO:TARGET   1225.1225 I: Executable deserialized
# 2023-06-30T13:38:57.821460Z popart:devicex 1225.1225 I: Setting selected device: Device Type:ipu Connection Type:always Id:0 Version:1.0.56 NumIPUs:1 NumTilesPerIPU:1472 DeviceIds: {0}
# 2023-06-30T13:38:57.821486Z popart:devicex 1225.1225 I: Setting engine options for prefetch data streams (exchange.streamBufferOverlap = hostRearrangeOnly, exchange.enablePrefetch = true
# 2023-06-30T13:38:57.821493Z popart:devicex 1225.1225 I: Setting engine option debug.retainDebugInformation = false
# 2023-06-30T13:38:57.821497Z popart:devicex 1225.1225 I: Setting engine option opt.useAutoloader = true
# 2023-06-30T13:38:57.821501Z popart:devicex 1225.1225 I: Setting engine option target.syncReplicasIndependently = true
# 2023-06-30T13:38:57.821627Z PO:ENGINE   1225.1225 I: Poplar Engine Options are clear
# 2023-06-30T13:38:57.822095Z popart:devicex 1225.1225 I:
# Next step is poplar Engine creation. Breakdown of compile time so far:
# Scope                                      Time [s]         Count  Percentage
# -----                                      --------         -----  ----------
# Preparing IR                               0.043486           504         8 %
# Constructing forwards (Ir)                 0.025607           108         5 %
# Scheduling. TCOs=1 Refine=1 CacheHit=Cold  0.009437             1         2 %
# Total                                      0.529788           n/a       100 %
# Unaccounted for                            0.442208           n/a        83 %
# Accounted for                              0.087580           n/a        17 %
#
# 2023-06-30T13:38:57.822114Z popart:devicex 1225.1225 I: Returning CachedExecutable
# Graph compilation: 100%|██████████| 100/100 [00:00<00:00]
# 2023-06-30T13:38:57.823627Z PO:ENGINE   1225.1225 I: Poplar Engine Options are clear
# 2023-06-30T13:38:57.824395Z popart:devicex 1225.1225 I:
# poplar Engine construction complete. Breakdown of compile time:
# Scope                                      Time [s]         Count  Percentage
# -----                                      --------         -----  ----------
# Preparing IR                               0.043486           504         8 %
# Constructing forwards (Ir)                 0.025607           108         5 %
# Scheduling. TCOs=1 Refine=1 CacheHit=Cold  0.009437             1         2 %
# Total                                      0.532094           n/a       100 %
# Unaccounted for                            0.442209           n/a        83 %
# Accounted for                              0.089885           n/a        17 %
#
# 2023-06-30T13:38:57.825764Z PO:ENGINE   1225.1225 I: Attached to device 0
# 2023-06-30T13:38:57.826028Z PO:ENGINE   1225.1225 I: Starting phase: Preparing to load executable
# 2023-06-30T13:38:57.826049Z PO:TARGET   1225.1225 I: Poplar exe compiled with 1 replicas for a V-IPU partition configured for 1 replicas
# 2023-06-30T13:38:57.872389Z PO:TARGET   1225.1225 I: IPUDevice::configureLinks apply true
# 2023-06-30T13:38:57.872406Z PO:TARGET   1225.1225 I: Sync group[0][0] = master 0; ipus {0}
# 2023-06-30T13:38:57.872409Z PO:TARGET   1225.1225 I: Sync group[1][0] = master 0; ipus {0}
# 2023-06-30T13:38:57.903026Z PO:TARGET   1225.1225 I: Loading secondary bootloader
# 2023-06-30T13:38:57.971895Z PO:TARGET   1225.1225 I: Finished device preparation
# 2023-06-30T13:38:57.971968Z PO:ENGINE   1225.1225 I:   Starting phase: Initialise Registers
# 2023-06-30T13:38:57.972280Z PO:PERF     1225.1225 I: Initialise Registers: real 0 ms; user 0 ms; sys 0 ms; max RSS: 1168.22 MiB; diff RSS: 0 total RSS: 1168.223000 MiB; current heap usage: 0.000000 MiB
# 2023-06-30T13:38:57.972285Z PO:ENGINE   1225.1225 I:   Ending phase: Initialise Registers
# 2023-06-30T13:38:57.972320Z PO:PERF     1225.1225 I: Preparing to load executable: real 146 ms; user 2 ms; sys 39 ms; diff RSS: 1.57812 total RSS: 1168.223000 MiB; current heap usage: 0.000000 MiB
# 2023-06-30T13:38:57.972323Z PO:ENGINE   1225.1225 I: Ending phase: Preparing to load executable
# 2023-06-30T13:38:57.972368Z PO:ENGINE   1225.1225 I: Starting phase: Loading executable
# 2023-06-30T13:38:57.972405Z PO:ENGINE   1225.1225 I:   Starting phase: Load IPU Executable
# 2023-06-30T13:38:58.253115Z PO:TARGET   1225.1225 I: Begin Loading [0-0]
# 2023-06-30T13:38:58.522380Z PO:TARGET   1225.1225 I: End Loading [0-0]
# 2023-06-30T13:38:58.522424Z PO:TARGET   1225.1225 I: Starting application
# 2023-06-30T13:38:58.522434Z PO:TARGET   1225.1225 I: App started by secondary loader
# 2023-06-30T13:38:58.853561Z PO:PERF     1225.1225 I: Load IPU Executable: real 880 ms; user 280 ms; sys 583 ms; max RSS: 2539.84 MiB; diff RSS: 1371.62 total RSS: 2539.844000 MiB; current heap usage: 0.000000 MiB
# 2023-06-30T13:38:58.853583Z PO:ENGINE   1225.1225 I:   Ending phase: Load IPU Executable
# 2023-06-30T13:38:58.909049Z PO:PERF     1225.1225 I: Loading executable: real 936 ms; user 280 ms; sys 639 ms; diff RSS: -1.39844 total RSS: 1166.825000 MiB; current heap usage: 0.000000 MiB
# 2023-06-30T13:38:58.909067Z PO:ENGINE   1225.1225 I: Ending phase: Loading executable
# 2023-06-30T13:38:58.909084Z popart:devicex 1225.1225 I: Engine loaded
# 2023-06-30T13:38:58.909334Z popart:devicex 1225.1225 I: [StepIOSplitter] Resetting StepIOSplitter.
# 2023-06-30T13:38:58.931879Z popart:devicex 1225.1225 I: [StepIOSplitter] Resetting StepIOSplitter.
# 2023-06-30T13:38:58.931895Z popart:devicex 1225.1225 I: [StepIOSplitter] Resetting StepIOSplitter.

# %%
print("Compilation succeeded, end of test.")
pipelined_model.detachFromDevice()

# %%
# !pip list
